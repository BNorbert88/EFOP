# %%
import torch as th
from skimage import io
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
files1 = [
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/1-2019-12-05-14-56-44-272782.jpg",
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/1-2019-12-05-14-57-26-768456.jpg",
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/1-2019-12-05-14-58-39-184989.jpg"
]
files2 = [
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/2-2019-12-05-14-56-47-984300.jpg",
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/2-2019-12-05-14-57-30-903597.jpg",
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/2-2019-12-05-14-58-42-936891.jpg"
]
files3 = [
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/3-2019-12-05-14-56-51-377830.jpg",
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/3-2019-12-05-14-57-34-397650.jpg",
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/3-2019-12-05-14-58-46-328783.jpg"
]
files4 = [
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/4-2019-12-05-14-56-54-761813.jpg",
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/4-2019-12-05-14-57-43-309734.jpg",
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/4-2019-12-05-14-58-49-730534.jpg"
]
files5 = [
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/5-2019-12-05-14-56-58-813382.jpg",
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/5-2019-12-05-14-57-47-014155.jpg",
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/5-2019-12-05-14-58-53-523468.jpg"
]
files6 = [
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/6-2019-12-05-14-57-06-225526.jpg",
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/6-2019-12-05-14-57-50-380355.jpg",
  "drive/My Drive/Bosch_kollaborativ/weather_cam_images/6-2019-12-05-14-58-56-900847.jpg"
]
files = files6
images = th.stack([th.tensor(io.imread(f)) for f in files])
images.shape
# Out:
# torch.Size([3, 288, 352, 3])

# %%
plt.imshow(images[0,:,:,0].numpy(), cmap="Greys")
plt.show()
plt.imshow(images[2])
plt.show()

# %%
median = th.median(images, dim=0)[0]
plt.imshow(median.numpy())
plt.show()
io.imsave("hihi.jpg", median.numpy())
